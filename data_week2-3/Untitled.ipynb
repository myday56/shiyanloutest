# %%
import pandas as pd

# %%
import numpy as np

# %%
df_data = pd.read_excel("ClimateChange.xlsx",sheet_name="Data")

# %%
df_country = pd.read_excel("ClimateChange.xlsx",sheet_name="Country")

# %%
df_data
# Out:
#       Country code                    Country name     Series code  \
# 0              ABW                           Aruba  AG.LND.EL5M.ZS
# 1              ADO                         Andorra  AG.LND.EL5M.ZS
# 2              AFG                     Afghanistan  AG.LND.EL5M.ZS
# 3              AGO                          Angola  AG.LND.EL5M.ZS
# 4              ALB                         Albania  AG.LND.EL5M.ZS
# 5              ARE            United Arab Emirates  AG.LND.EL5M.ZS
# 6              ARG                       Argentina  AG.LND.EL5M.ZS
# 7              ARM                         Armenia  AG.LND.EL5M.ZS
# 8              ASM                  American Samoa  AG.LND.EL5M.ZS
# 9              ATG             Antigua and Barbuda  AG.LND.EL5M.ZS
# 10             AUS                       Australia  AG.LND.EL5M.ZS
# 11             AUT                         Austria  AG.LND.EL5M.ZS
# 12             AZE                      Azerbaijan  AG.LND.EL5M.ZS
# ...

# %%
df_series = pd.read_excel("ClimateChange.xlsx",sheet_name="Series")

# %%
df_data.head()
# Out:
#   Country code Country name     Series code  \
# 0          ABW        Aruba  AG.LND.EL5M.ZS
# 1          ADO      Andorra  AG.LND.EL5M.ZS
# 2          AFG  Afghanistan  AG.LND.EL5M.ZS
# 3          AGO       Angola  AG.LND.EL5M.ZS
# 4          ALB      Albania  AG.LND.EL5M.ZS
#
#                            Series name SCALE Decimals      1990 1991 1992  \
# 0  Land area below 5m (% of land area)     0        1   29.5748   ..   ..
# 1  Land area below 5m (% of land area)     0        1         0   ..   ..
# 2  Land area below 5m (% of land area)     0        1         0   ..   ..
# 3  Land area below 5m (% of land area)     0        1  0.208235   ..   ..
# 4  Land area below 5m (% of land area)     0        1   4.96788   ..   ..
#
#   1993 ...  2002 2003 2004 2005 2006 2007 2008 2009 2010 2011
# 0   .. ...    ..   ..   ..   ..   ..   ..   ..   ..   ..   ..
# 1   .. ...    ..   ..   ..   ..   ..   ..   ..   ..   ..   ..
# 2   .. ...    ..   ..   ..   ..   ..   ..   ..   ..   ..   ..
# ...

# %%
df_country.groupby('Income group').count()
# Out:
#                       Country code  Country name  Capital city  Region  \
# Income group
# High income: OECD               31            31            31      31
# High income: nonOECD            39            39            39      39
# Low income                      35            35            35      35
# Lower middle income             56            56            56      56
# Upper middle income             57            57            57      57
#
#                       Lending category
# Income group
# High income: OECD                   31
# High income: nonOECD                39
# Low income                          35
# Lower middle income                 56
# Upper middle income                 57

# %%
df_country_1 = pd.DataFrame(df_country,columns=['Country code','Country name','SCALE'])

# %%
pd.merge(df_data,df_country,on='Country code')
# Out:
#       Country code Country name_x           Series code  \
# 0              ABW          Aruba        AG.LND.EL5M.ZS
# 1              ABW          Aruba     AG.LND.IRIG.AG.ZS
# 2              ABW          Aruba        AG.YLD.CREL.KG
# 3              ABW          Aruba  BX.KLT.DINV.WD.GD.ZS
# 4              ABW          Aruba        EG.ELC.ACCS.ZS
# 5              ABW          Aruba  EG.USE.COMM.GD.PP.KD
# 6              ABW          Aruba     EG.USE.PCAP.KG.OE
# 7              ABW          Aruba        EN.ATM.CO2E.KT
# 8              ABW          Aruba        EN.ATM.CO2E.PC
# 9              ABW          Aruba  EN.ATM.CO2E.PP.GD.KD
# 10             ABW          Aruba     EN.ATM.GHGO.KT.CE
# 11             ABW          Aruba     EN.ATM.METH.KT.CE
# 12             ABW          Aruba     EN.ATM.NOXE.KT.CE
# 13             ABW          Aruba           EN.CLC.AERT
# 14             ABW          Aruba        EN.CLC.DRSK.XQ
# 15             ABW          Aruba     EN.CLC.GHGR.MT.CE
# ...

# %%
df_new_data = pd.merge(df_data,df_country,on='Country code').drop(['Series name','SCALE','Decimals','Country name_y','Capital city','Region','Lending category'],axis=1)

# %%
df_new_data
# Out:
#       Country code Country name_x           Series code         1990  \
# 0              ABW          Aruba        AG.LND.EL5M.ZS      29.5748
# 1              ABW          Aruba     AG.LND.IRIG.AG.ZS           ..
# 2              ABW          Aruba        AG.YLD.CREL.KG           ..
# 3              ABW          Aruba  BX.KLT.DINV.WD.GD.ZS           ..
# 4              ABW          Aruba        EG.ELC.ACCS.ZS           ..
# 5              ABW          Aruba  EG.USE.COMM.GD.PP.KD           ..
# 6              ABW          Aruba     EG.USE.PCAP.KG.OE           ..
# 7              ABW          Aruba        EN.ATM.CO2E.KT      1840.83
# 8              ABW          Aruba        EN.ATM.CO2E.PC      29.6206
# 9              ABW          Aruba  EN.ATM.CO2E.PP.GD.KD           ..
# 10             ABW          Aruba     EN.ATM.GHGO.KT.CE           ..
# 11             ABW          Aruba     EN.ATM.METH.KT.CE           ..
# 12             ABW          Aruba     EN.ATM.NOXE.KT.CE           ..
# ...

# %%
df_new_data_1 = df_new_data[df_new_data['Series code']=='EN.ATM.CO2E.KT']

# %%
df_new_data_1
# Out:
#       Country code                  Country name_x     Series code  \
# 7              ABW                           Aruba  EN.ATM.CO2E.KT
# 65             ADO                         Andorra  EN.ATM.CO2E.KT
# 123            AFG                     Afghanistan  EN.ATM.CO2E.KT
# 181            AGO                          Angola  EN.ATM.CO2E.KT
# 239            ALB                         Albania  EN.ATM.CO2E.KT
# 297            ARE            United Arab Emirates  EN.ATM.CO2E.KT
# 355            ARG                       Argentina  EN.ATM.CO2E.KT
# 413            ARM                         Armenia  EN.ATM.CO2E.KT
# 471            ASM                  American Samoa  EN.ATM.CO2E.KT
# 529            ATG             Antigua and Barbuda  EN.ATM.CO2E.KT
# 587            AUS                       Australia  EN.ATM.CO2E.KT
# 645            AUT                         Austria  EN.ATM.CO2E.KT
# 703            AZE                      Azerbaijan  EN.ATM.CO2E.KT
# ...

# %%
df_new_data_2 = df_new_data_1.replace('..',np.nan).fillna(method='bfill')

# %%
df_new_data_2.head()
# Out:
#     Country code Country name_x     Series code      1990      1991      1992  \
# 7            ABW          Aruba  EN.ATM.CO2E.KT  1840.834  1928.842  1723.490
# 65           ADO        Andorra  EN.ATM.CO2E.KT  2676.910  2493.560  1426.463
# 123          AFG    Afghanistan  EN.ATM.CO2E.KT  2676.910  2493.560  1426.463
# 181          AGO         Angola  EN.ATM.CO2E.KT  4429.736  4367.397  4418.735
# 239          ALB        Albania  EN.ATM.CO2E.KT  7488.014  3971.361  2387.217
#
#          1993      1994       1995       1996          ...               2003  \
# 7    1771.161  1763.827   1785.829   1811.498          ...           2255.205
# 65   1375.125  1320.120    407.037    425.372          ...            535.382
# 123  1375.125  1320.120   1268.782   1199.109          ...            583.053
# 181  5801.194  3890.687  11012.001  10491.287          ...           9064.824
# 239  2343.213  1928.842   2086.523   2016.850          ...           4290.390
#
# ...

# %%
df_new_data_3 = df_new_data_2.fillna(method='ffill',axis=1)

# %%
df_final_data = df_new_data_3.fillna(method='ffill')

# %%
df_final_data.icol(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-118-ced8ed155823> in <module>()
# ----> 1 df_final_data.icol(0)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'icol'
